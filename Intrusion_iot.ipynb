# %% [markdown]
# <a href="https://colab.research.google.com/github/Keerthan22-sys/Intrusion_IoT/blob/main/Intrusion_iot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("./IoT_Intrusion.csv")

# %% [markdown]
# # Data exploration

# %%
df
# Out:
#          flow_duration  Header_Length  Protocol Type  Duration         Rate  \
# 0             0.000000          54.00           6.00     64.00     0.329807
# 1             0.000000          57.04           6.33     64.00     4.290556
# 2             0.000000           0.00           1.00     64.00    33.396799
# 3             0.328175       76175.00          17.00     64.00  4642.133010
# 4             0.117320         101.73           6.11     65.91     6.202211
# ...                ...            ...            ...       ...          ...
# 1048570       1.391925         108.00           6.00     64.00     1.437685
# 1048571       0.000000           2.14          46.70     65.91     0.000000
# 1048572       0.132971       30847.00          17.00     64.00  5978.034950
# 1048573       0.000000          54.00           6.00     64.00    25.672981
# 1048574     128.443556        4264.30           7.10     98.80    13.640648
#
#                Srate  Drate  fin_flag_number  syn_flag_number  \
# 0           0.329807    0.0                1                0
# 1           4.290556    0.0                0                0
# 2          33.396799    0.0                0                0
# 3        4642.133010    0.0                0                0
# 4           6.202211    0.0                0                1
# ...              ...    ...              ...              ...
# 1048570     1.437685    0.0                0                1
# 1048571     0.000000    0.0                0                0
# 1048572  5978.034950    0.0                0                0
# 1048573    25.672981    0.0                1                0
# 1048574    13.640648    0.0                0                0
#
#          rst_flag_number  ...         Std  Tot size           IAT  Number  \
# 0                      1  ...    0.000000     54.00  8.334383e+07     9.5
# 1                      0  ...    2.822973     57.04  8.292607e+07     9.5
# 2                      0  ...    0.000000     42.00  8.312799e+07     9.5
# 3                      0  ...    0.000000     50.00  8.301570e+07     9.5
# 4                      0  ...   23.113111     57.88  8.297300e+07     9.5
# ...                  ...  ...         ...       ...           ...     ...
# 1048570                0  ...    0.000000     54.00  8.336550e+07     9.5
# 1048571                0  ...    5.281048    588.22  8.367732e+07     9.5
# 1048572                0  ...    0.000000     50.00  8.312373e+07     9.5
# 1048573                1  ...    0.000000     54.00  8.334509e+07     9.5
# 1048574                0  ...  114.400450     96.70  1.665173e+08    13.5
#
#           Magnitue      Radius    Covariance  Variance  Weight  \
# 0        10.392305    0.000000      0.000000      0.00  141.55
# 1        10.464666    4.010353    160.987842      0.05  141.55
# 2         9.165151    0.000000      0.000000      0.00  141.55
# 3        10.000000    0.000000      0.000000      0.00  141.55
# 4        11.346876   32.716243   3016.808286      0.19  141.55
# ...            ...         ...           ...       ...     ...
# 1048570  10.392305    0.000000      0.000000      0.00  141.55
# 1048571  34.370618    7.497140    469.190222      0.06  141.55
# 1048572  10.000000    0.000000      0.000000      0.00  141.55
# 1048573  10.392305    0.000000      0.000000      0.00  141.55
# 1048574  17.124571  162.030508  13140.079760      1.00  244.60
#
#                            label
# 0               DDoS-RSTFINFlood
# 1                  DoS-TCP_Flood
# 2                DDoS-ICMP_Flood
# 3                  DoS-UDP_Flood
# 4                  DoS-SYN_Flood
# ...                          ...
# 1048570  DDoS-SynonymousIP_Flood
# 1048571       Mirai-greeth_flood
# 1048572           DDoS-UDP_Flood
# 1048573         DDoS-RSTFINFlood
# 1048574            BenignTraffic
#
# [1048575 rows x 47 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 47 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   flow_duration    1048575 non-null  float64
#  1   Header_Length    1048575 non-null  float64
#  2   Protocol Type    1048575 non-null  float64
#  3   Duration         1048575 non-null  float64
#  4   Rate             1048575 non-null  float64
#  5   Srate            1048575 non-null  float64
#  6   Drate            1048575 non-null  float64
#  7   fin_flag_number  1048575 non-null  int64
#  8   syn_flag_number  1048575 non-null  int64
#  9   rst_flag_number  1048575 non-null  int64
#  10  psh_flag_number  1048575 non-null  int64
#  11  ack_flag_number  1048575 non-null  int64
#  12  ece_flag_number  1048575 non-null  int64
#  13  cwr_flag_number  1048575 non-null  int64
#  14  ack_count        1048575 non-null  float64
#  15  syn_count        1048575 non-null  float64
#  16  fin_count        1048575 non-null  float64
#  17  urg_count        1048575 non-null  float64
#  18  rst_count        1048575 non-null  float64
#  19  HTTP             1048575 non-null  int64
#  20  HTTPS            1048575 non-null  int64
#  21  DNS              1048575 non-null  int64
#  22  Telnet           1048575 non-null  int64
#  23  SMTP             1048575 non-null  int64
#  24  SSH              1048575 non-null  int64
#  25  IRC              1048575 non-null  int64
#  26  TCP              1048575 non-null  int64
#  27  UDP              1048575 non-null  int64
#  28  DHCP             1048575 non-null  int64
#  29  ARP              1048575 non-null  int64
#  30  ICMP             1048575 non-null  int64
#  31  IPv              1048575 non-null  int64
#  32  LLC              1048575 non-null  int64
#  33  Tot sum          1048575 non-null  float64
#  34  Min              1048575 non-null  float64
#  35  Max              1048575 non-null  float64
#  36  AVG              1048575 non-null  float64
#  37  Std              1048575 non-null  float64
#  38  Tot size         1048575 non-null  float64
#  39  IAT              1048575 non-null  float64
#  40  Number           1048575 non-null  float64
#  41  Magnitue         1048575 non-null  float64
#  42  Radius           1048575 non-null  float64
#  43  Covariance       1048575 non-null  float64
#  44  Variance         1048575 non-null  float64
#  45  Weight           1048575 non-null  float64
#  46  label            1048575 non-null  object
# dtypes: float64(25), int64(21), object(1)
# memory usage: 376.0+ MB

# %%
tmp_sorted_df = df.groupby(by="label").agg("count").sort_values(by="flow_duration", ascending=False)
labels, counts = tmp_sorted_df["flow_duration"].index, tmp_sorted_df["flow_duration"].values

# %%
len(labels)
# Out:
# 34

# %%
plt.figure(figsize=(8, 10))
plt.barh(labels, counts)
plt.show()

# %% [markdown]
# # Categorical data

# %%
df.columns
# Out:
# Index(['flow_duration', 'Header_Length', 'Protocol Type', 'Duration', 'Rate',
#        'Srate', 'Drate', 'fin_flag_number', 'syn_flag_number',
#        'rst_flag_number', 'psh_flag_number', 'ack_flag_number',
#        'ece_flag_number', 'cwr_flag_number', 'ack_count', 'syn_count',
#        'fin_count', 'urg_count', 'rst_count', 'HTTP', 'HTTPS', 'DNS', 'Telnet',
#        'SMTP', 'SSH', 'IRC', 'TCP', 'UDP', 'DHCP', 'ARP', 'ICMP', 'IPv', 'LLC',
#        'Tot sum', 'Min', 'Max', 'AVG', 'Std', 'Tot size', 'IAT', 'Number',
#        'Magnitue', 'Radius', 'Covariance', 'Variance', 'Weight', 'label'],
#       dtype='object')

# %%
categorical_data = [row for row in df.columns if len(pd.unique(df[row])) <= 2]
categorical_data
# Out:
# ['fin_flag_number',
#  'syn_flag_number',
#  'rst_flag_number',
#  'psh_flag_number',
#  'ack_flag_number',
#  'ece_flag_number',
#  'cwr_flag_number',
#  'HTTP',
#  'HTTPS',
#  'DNS',
#  'Telnet',
#  'SMTP',
#  'SSH',
#  'IRC',
#  'TCP',
#  'UDP',
#  'DHCP',
#  'ARP',
#  'ICMP',
#  'IPv',
#  'LLC']

# %%
df[categorical_data].hist(figsize=(25, 25))
# Out:
# array([[<Axes: title={'center': 'fin_flag_number'}>,
#         <Axes: title={'center': 'syn_flag_number'}>,
#         <Axes: title={'center': 'rst_flag_number'}>,
#         <Axes: title={'center': 'psh_flag_number'}>,
#         <Axes: title={'center': 'ack_flag_number'}>],
#        [<Axes: title={'center': 'ece_flag_number'}>,
#         <Axes: title={'center': 'cwr_flag_number'}>,
#         <Axes: title={'center': 'HTTP'}>,
#         <Axes: title={'center': 'HTTPS'}>,
#         <Axes: title={'center': 'DNS'}>],
#        [<Axes: title={'center': 'Telnet'}>,
#         <Axes: title={'center': 'SMTP'}>,
#         <Axes: title={'center': 'SSH'}>, <Axes: title={'center': 'IRC'}>,
#         <Axes: title={'center': 'TCP'}>],
#        [<Axes: title={'center': 'UDP'}>,
#         <Axes: title={'center': 'DHCP'}>,
#         <Axes: title={'center': 'ARP'}>,
#         <Axes: title={'center': 'ICMP'}>,
#         <Axes: title={'center': 'IPv'}>],
#        [<Axes: title={'center': 'LLC'}>, <Axes: >, <Axes: >, <Axes: >,
#         <Axes: >]], dtype=object)

# %%
for column in categorical_data:
    print(np.unique(df[column], return_counts=True))
# Out:
# (array([0, 1]), array([957812,  90763]))
# (array([0, 1]), array([831196, 217379]))
# (array([0, 1]), array([953604,  94971]))
# (array([0, 1]), array([956193,  92382]))
# (array([0, 1]), array([918708, 129867]))
# (array([0]), array([1048575]))
# (array([0]), array([1048575]))
# (array([0, 1]), array([997735,  50840]))
# (array([0, 1]), array([990633,  57942]))
# (array([0, 1]), array([1048433,     142]))
# (array([0]), array([1048575]))
# (array([0]), array([1048575]))
# (array([0, 1]), array([1048512,      63]))
# (array([0]), array([1048575]))
# (array([0, 1]), array([446278, 602297]))
# (array([0, 1]), array([826349, 222226]))
# (array([0, 1]), array([1048573,       2]))
# (array([0, 1]), array([1048505,      70]))
# (array([0, 1]), array([877307, 171268]))
# (array([0, 1]), array([    119, 1048456]))
# (array([0, 1]), array([    119, 1048456]))

# %%
def valid_categorical_features_selector(dataframe, total_categorical_data):
    result = []

    for column in categorical_data:
        elements, counts = np.unique(df[column], return_counts=True)

        if not (elements.shape[0] == 1 or counts[0] < 150 or counts[1] < 150):
            result.append(column)

    return result

# %%
valid_categorical_data = valid_categorical_features_selector(df, categorical_data)
valid_categorical_data
# Out:
# ['fin_flag_number',
#  'syn_flag_number',
#  'rst_flag_number',
#  'psh_flag_number',
#  'ack_flag_number',
#  'HTTP',
#  'HTTPS',
#  'TCP',
#  'UDP',
#  'ICMP']

# %%
df[valid_categorical_data].hist(figsize=(25, 25))
# Out:
# array([[<Axes: title={'center': 'fin_flag_number'}>,
#         <Axes: title={'center': 'syn_flag_number'}>,
#         <Axes: title={'center': 'rst_flag_number'}>],
#        [<Axes: title={'center': 'psh_flag_number'}>,
#         <Axes: title={'center': 'ack_flag_number'}>,
#         <Axes: title={'center': 'HTTP'}>],
#        [<Axes: title={'center': 'HTTPS'}>,
#         <Axes: title={'center': 'TCP'}>, <Axes: title={'center': 'UDP'}>],
#        [<Axes: title={'center': 'ICMP'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %% [markdown]
# # **Numeric data**

# %%
numeric_data = [row for row in df.columns if row not in categorical_data]
numeric_data
# Out:
# ['flow_duration',
#  'Header_Length',
#  'Protocol Type',
#  'Duration',
#  'Rate',
#  'Srate',
#  'Drate',
#  'ack_count',
#  'syn_count',
#  'fin_count',
#  'urg_count',
#  'rst_count',
#  'Tot sum',
#  'Min',
#  'Max',
#  'AVG',
#  'Std',
#  'Tot size',
#  'IAT',
#  'Number',
#  'Magnitue',
#  'Radius',
#  'Covariance',
#  'Variance',
#  'Weight',
#  'label']

# %%
df[numeric_data].hist(figsize=(25, 25), bins=3)
# Out:
# array([[<Axes: title={'center': 'flow_duration'}>,
#         <Axes: title={'center': 'Header_Length'}>,
#         <Axes: title={'center': 'Protocol Type'}>,
#         <Axes: title={'center': 'Duration'}>,
#         <Axes: title={'center': 'Rate'}>],
#        [<Axes: title={'center': 'Srate'}>,
#         <Axes: title={'center': 'Drate'}>,
#         <Axes: title={'center': 'ack_count'}>,
#         <Axes: title={'center': 'syn_count'}>,
#         <Axes: title={'center': 'fin_count'}>],
#        [<Axes: title={'center': 'urg_count'}>,
#         <Axes: title={'center': 'rst_count'}>,
#         <Axes: title={'center': 'Tot sum'}>,
#         <Axes: title={'center': 'Min'}>, <Axes: title={'center': 'Max'}>],
#        [<Axes: title={'center': 'AVG'}>, <Axes: title={'center': 'Std'}>,
#         <Axes: title={'center': 'Tot size'}>,
#         <Axes: title={'center': 'IAT'}>,
#         <Axes: title={'center': 'Number'}>],
#        [<Axes: title={'center': 'Magnitue'}>,
#         <Axes: title={'center': 'Radius'}>,
#         <Axes: title={'center': 'Covariance'}>,
#         <Axes: title={'center': 'Variance'}>,
#         <Axes: title={'center': 'Weight'}>]], dtype=object)

# %%
# A column will be considered as able to be transformed via standardization if less data instances than the specified threshold are discarded when we trim the data up to 3sigma
def get_columns_for_standard_scaling(dataframe, numeric_cols, threshold):
    result = []

    for column in numeric_cols:
        column_std_3 = 3*dataframe[column].std()
        column_mean = dataframe[column].mean()
        total_data = dataframe[column].count()
        data_after_3_std = dataframe.loc[(dataframe[column]) < (column_mean + column_std_3)][column].count()

        if (total_data - data_after_3_std) < threshold:
            result.append(column)

    return result

# %%
valid_numeric_columns_for_standardization = get_columns_for_standard_scaling(df, numeric_data[:-1], 20000)
print(valid_numeric_columns_for_standardization)
print(len(valid_numeric_columns_for_standardization))
# Out:
# ['flow_duration', 'Header_Length', 'Duration', 'Rate', 'Srate', 'Drate', 'fin_count', 'urg_count', 'rst_count', 'Max', 'Covariance']
# 11

# %%
def outliers_dropping_based_in_3sigma(dataframe, numeric_cols_to_trim):

    for column in numeric_cols_to_trim:
        column_mean = dataframe[column].mean()
        column_3_sigma = 3*dataframe[column].std()

        dataframe = dataframe[(dataframe[column]) < (column_mean + column_3_sigma)]

    return dataframe

# %%
prueba_df = outliers_dropping_based_in_3sigma(df, valid_numeric_columns_for_standardization)

# %%
prueba_df[valid_numeric_columns_for_standardization].hist(figsize=(25, 15), bins=25)
# Out:
# array([[<Axes: title={'center': 'flow_duration'}>,
#         <Axes: title={'center': 'Header_Length'}>,
#         <Axes: title={'center': 'Duration'}>],
#        [<Axes: title={'center': 'Rate'}>,
#         <Axes: title={'center': 'Srate'}>,
#         <Axes: title={'center': 'Drate'}>],
#        [<Axes: title={'center': 'fin_count'}>,
#         <Axes: title={'center': 'urg_count'}>,
#         <Axes: title={'center': 'rst_count'}>],
#        [<Axes: title={'center': 'Max'}>,
#         <Axes: title={'center': 'Covariance'}>, <Axes: >]], dtype=object)

# %% [markdown]
# # **Cambios en la variable objetivo**

# %%
all_labels = pd.unique(df["label"])

# %%
all_labels
# Out:
# array(['DDoS-RSTFINFlood', 'DoS-TCP_Flood', 'DDoS-ICMP_Flood',
#        'DoS-UDP_Flood', 'DoS-SYN_Flood', 'Mirai-greeth_flood',
#        'DDoS-SynonymousIP_Flood', 'Mirai-udpplain', 'DDoS-SYN_Flood',
#        'DDoS-PSHACK_Flood', 'DDoS-TCP_Flood', 'DDoS-UDP_Flood',
#        'BenignTraffic', 'MITM-ArpSpoofing', 'DDoS-ACK_Fragmentation',
#        'Mirai-greip_flood', 'DoS-HTTP_Flood', 'DDoS-ICMP_Fragmentation',
#        'Recon-PortScan', 'DNS_Spoofing', 'DDoS-UDP_Fragmentation',
#        'Recon-OSScan', 'XSS', 'DDoS-HTTP_Flood', 'Recon-HostDiscovery',
#        'CommandInjection', 'VulnerabilityScan', 'DDoS-SlowLoris',
#        'Backdoor_Malware', 'BrowserHijacking', 'DictionaryBruteForce',
#        'SqlInjection', 'Recon-PingSweep', 'Uploading_Attack'],
#       dtype=object)

# %%
def no_underscore_labels_eraser(dataframe):
  return dataframe[(dataframe["label"].str.find("-") != -1) &
                   (dataframe["label"].str.find("-") != -1) |
                   (dataframe["label"] == "BenignTraffic")]

# %%
def label_transformer(label: str):
  if label == "BenignTraffic":
    return label

  character = "-" if "-" in label else "_"

  return label.split(character)[0]

# %%
def label_selection(dataframe):
  no_underscore_df = no_underscore_labels_eraser(dataframe)
  label_transformer_vec = np.vectorize(label_transformer)
  return label_transformer_vec(no_underscore_df["label"])

# %%
tmp_counter = 0
no_underscore_columns = []

for info in all_labels:

  if info.find("BenignTraffic") != -1:
    continue

  if info.find("-") == -1 and info.find("_") == -1:
    tmp_counter += 1
    no_underscore_columns.append(info)

print(no_underscore_columns)
tmp_counter/all_labels.shape[0]
# Out:
# ['XSS', 'CommandInjection', 'VulnerabilityScan', 'BrowserHijacking', 'DictionaryBruteForce', 'SqlInjection']
# 0.17647058823529413

# %%
selected_lables = label_selection(df)
pd.unique(selected_lables)
# Out:
# array(['DDoS', 'DoS', 'Mirai', 'BenignTraffic', 'MITM', 'Recon'],
#       dtype='<U13')

# %%
print(selected_lables.shape, df.shape[0])
# Out:
# (1042870,) 1048575

# %%
df_with_selected_labels = no_underscore_labels_eraser(df)
df_with_selected_labels.loc[:,"final_label"] = selected_lables
# Out:
# /var/folders/0k/h69y1k5x1s5_4vf5fj9hbrkr0000gn/T/ipykernel_5467/3074786927.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_with_selected_labels.loc[:,"final_label"] = selected_lables

# %%
df_with_selected_labels.loc[:15, ["label", "final_label"]]
# Out:
#                       label final_label
# 0          DDoS-RSTFINFlood        DDoS
# 1             DoS-TCP_Flood         DoS
# 2           DDoS-ICMP_Flood        DDoS
# 3             DoS-UDP_Flood         DoS
# 4             DoS-SYN_Flood         DoS
# 5        Mirai-greeth_flood       Mirai
# 6   DDoS-SynonymousIP_Flood        DDoS
# 7            Mirai-udpplain       Mirai
# 8             DoS-UDP_Flood         DoS
# 9            DDoS-SYN_Flood        DDoS
# 10        DDoS-PSHACK_Flood        DDoS
# 11           DDoS-TCP_Flood        DDoS
# 12          DDoS-ICMP_Flood        DDoS
# 13            DoS-TCP_Flood         DoS
# 14          DDoS-ICMP_Flood        DDoS
# 15            DoS-TCP_Flood         DoS

# %%
final_label_columns, counts_per_column = np.unique(df_with_selected_labels["final_label"], return_counts=True)

plt.bar(final_label_columns, counts_per_column)
plt.show()

# %% [markdown]
# # **Creación del pipeline de preprocesamiento**

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OrdinalEncoder, OneHotEncoder

# %%
print(valid_categorical_data)
print(valid_numeric_columns_for_standardization)

len(valid_categorical_data) + len(valid_numeric_columns_for_standardization)
# Out:
# ['fin_flag_number', 'syn_flag_number', 'rst_flag_number', 'psh_flag_number', 'ack_flag_number', 'HTTP', 'HTTPS', 'TCP', 'UDP', 'ICMP']
# ['flow_duration', 'Header_Length', 'Duration', 'Rate', 'Srate', 'Drate', 'fin_count', 'urg_count', 'rst_count', 'Max', 'Covariance']
# 21

# %%
column_trans =  ColumnTransformer(
    [
        ("num", StandardScaler(), valid_numeric_columns_for_standardization),
        ("cat", OrdinalEncoder(), valid_categorical_data)
    ]
)

# %% [markdown]
# # **Generación del modelo**

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from keras.layers import Dense, Input, Dropout
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import Sequential, clone_model, load_model
from keras.regularizers import l2

# %% [markdown]
# **Separación de las variables y aplicación de preprocesamiento**

# %%
final_columns = valid_numeric_columns_for_standardization + valid_categorical_data + ["final_label"]
final_columns
# Out:
# ['flow_duration',
#  'Header_Length',
#  'Duration',
#  'Rate',
#  'Srate',
#  'Drate',
#  'fin_count',
#  'urg_count',
#  'rst_count',
#  'Max',
#  'Covariance',
#  'fin_flag_number',
#  'syn_flag_number',
#  'rst_flag_number',
#  'psh_flag_number',
#  'ack_flag_number',
#  'HTTP',
#  'HTTPS',
#  'TCP',
#  'UDP',
#  'ICMP',
#  'final_label']

# %%
X, y = df_with_selected_labels[final_columns[:-1]], df_with_selected_labels[final_columns[-1]]

# %%
from sklearn.preprocessing import LabelEncoder

label_enco = LabelEncoder()
y = label_enco.fit_transform(y.values.reshape(-1, 1))
class_names = label_enco.classes_
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (938583, 21)
# (104287, 21)
# (938583,)
# (104287,)

# %%
num_of_labels = len(np.unique(y_test))

# %%
num_of_labels
# Out:
# 6

# %% [markdown]
# **Definición de los modelos**

# %% [markdown]
# Con dropout y regularization

# %%
model_1 = Sequential(
   [
    Input((21,)),
    Dense(32, activation="relu"),
    Dense(64, activation="relu"),
    Dropout(0.2),
    Dense(128, activation="relu", kernel_regularizer=l2(0.1)),
    Dense(64, activation="relu"),
    Dropout(0.3),
    Dense(128, activation="relu"),
    Dense(64, activation="relu"),
    Dense(64, activation="relu", kernel_regularizer=l2(0.1)),
    Dropout(0.2),
    Dense(32, activation="relu"),
    Dense(32, activation="relu", kernel_regularizer=l2(0.1)),
    Dense(16, activation="relu"),
    Dropout(0.1),
    Dense(32, activation="relu", kernel_regularizer=l2(0.1)),
    Dense(64, activation="relu"),
    Dense(num_of_labels, activation="softmax")
    ]
)

# %% [markdown]
# Sin dropout ni regularization

# %%
model_2 = Sequential(
   [
    Input((21,)),
    Dense(32, activation="relu"),
    Dense(64, activation="relu"),
    Dense(128, activation="relu"),
    Dense(64, activation="relu"),
    Dense(128, activation="relu"),
    Dense(64, activation="relu"),
    Dense(64, activation="relu"),
    Dense(32, activation="relu"),
    Dense(32, activation="relu"),
    Dense(16, activation="relu"),
    Dense(32, activation="relu"),
    Dense(64, activation="relu"),
    Dense(num_of_labels, activation="softmax")
    ]
)

# %% [markdown]
# Con dropout y sin regularization

# %%
model_3 = Sequential(
   [
    Input((21,)),
    Dense(64, activation="relu"),
    Dropout(0.2),
    Dense(64, activation="relu"),
    Dense(128, activation="relu"),
    Dropout(0.3),
    Dense(64, activation="relu"),
    Dense(128, activation="relu"),
    Dense(64, activation="relu"),
    Dense(64, activation="relu"),
    Dropout(0.2),
    Dense(32, activation="relu"),
    Dense(32, activation="relu"),
    Dense(16, activation="relu"),
    Dropout(0.1),
    Dense(32, activation="relu"),
    Dense(64, activation="relu"),
    Dense(num_of_labels, activation="softmax")
    ]
)

# %%
def models_trainer(models_container: dict,
                   x_trn,
                   y_trn,
                   epochs: int,
                   checkpoint_path: str = ""
                   ):

  results = {}

  for name, model in models_container.items():

    model = clone_model(model)

    print(f"{name} model in training")

    checkpoint = ModelCheckpoint(
            f"{checkpoint_path}/{name}.keras",
            monitor= 'val_loss',
            verbose= 1,
            save_best_only= True,
        )

    early_stopping = EarlyStopping(
        monitor = "val_loss",
        patience = 10,
        verbose = 2
    )

    model.compile(
        optimizer = "adam",
        loss = "sparse_categorical_crossentropy",
        metrics=["accuracy"]
        )

    print(x_trn.shape, y_trn.shape)

    history = model.fit(
                x_trn,
                y_trn,
                batch_size=512,
                epochs=epochs,
                validation_split=0.1,
                callbacks = [checkpoint, early_stopping]
            )

    results[f"{name}"] = (history, model)

  return results

# %%
models = {
    "Complete_model": model_1,
    "Most_simple_model": model_2,
    "No_regularization_model": model_3
}

# %%
results = models_trainer(models, X_train, y_train, 100, "/Users/keerthangowdas/Documents/Intrusion/working")
# Out:
# Complete_model model in training
# (938583, 21) (938583,)
# Epoch 1/100
# 1645/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6915 - loss: 21.0151
# Epoch 1: val_loss improved from inf to 5.86668, saving model to /Users/keerthangowdas/Documents/Intrusion/working/Complete_model.keras
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.6916 - loss: 20.9842 - val_accuracy: 0.7859 - val_loss: 5.8667
# Epoch 2/100
# 1647/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7739 - loss: 4.5437
# Epoch 2: val_loss improved from 5.86668 to 1.73351, saving model to /Users/keerthangowdas/Documents/Intrusion/working/Complete_model.keras
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.7739 - loss: 4.5410 - val_accuracy: 0.7979 - val_loss: 1.7335
# Epoch 3/100
# 1648/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8052 - loss: 1.3713
# Epoch 3: val_loss improved from 1.73351 to 0.62253, saving model to /Users/keerthangowdas/Documents/Intrusion/working/Complete_model.keras
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8052 - loss: 1.3708 - val_accuracy: 0.8437 - val_loss: 0.6225
# Epoch 4/100
# 1642/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8375 - loss: 0.5672
# Epoch 4: val_loss improved from 0.62253 to 0.43343, saving model to /Users/keerthangowdas/Documents/Intrusion/working/Complete_model.keras
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8375 - loss: 0.5669 - val_accuracy: 0.8461 - val_loss: 0.4334
# Epoch 5/100
# 1641/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8496 - loss: 0.4279
# Epoch 5: val_loss improved from 0.43343 to 0.38290, saving model to /Users/keerthangowdas/Documents/Intrusion/working/Complete_model.keras
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8496 - loss: 0.4278 - val_accuracy: 0.8591 - val_loss: 0.3829
# Epoch 6/100
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8541 - loss: 0.3977
# Epoch 6: val_loss improved from 0.38290 to 0.36458, saving model to /Users/keerthangowdas/Documents/Intrusion/working/Complete_model.keras
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8541 - loss: 0.3977 - val_accuracy: 0.8608 - val_loss: 0.3646
# Epoch 7/100
# 1644/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8590 - loss: 0.3815
# Epoch 7: val_loss improved from 0.36458 to 0.36435, saving model to /Users/keerthangowdas/Documents/Intrusion/working/Complete_model.keras
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8590 - loss: 0.3815 - val_accuracy: 0.8629 - val_loss: 0.3644
# Epoch 8/100
# 1635/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8613 - loss: 0.3705
# Epoch 8: val_loss improved from 0.36435 to 0.34279, saving model to /Users/keerthangowdas/Documents/Intrusion/working/Complete_model.keras
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8613 - loss: 0.3705 - val_accuracy: 0.8696 - val_loss: 0.3428
# Epoch 9/100
# 1635/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8643 - loss: 0.3599
# Epoch 9: val_loss did not improve from 0.34279
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8643 - loss: 0.3599 - val_accuracy: 0.8667 - val_loss: 0.3559
# Epoch 10/100
# 1638/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8680 - loss: 0.3494
# Epoch 10: val_loss did not improve from 0.34279
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8680 - loss: 0.3494 - val_accuracy: 0.8623 - val_loss: 0.3568
# Epoch 11/100
# 1644/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8677 - loss: 0.3652
# Epoch 11: val_loss did not improve from 0.34279
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8677 - loss: 0.3652 - val_accuracy: 0.8696 - val_loss: 0.3442
# Epoch 12/100
# 1648/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8693 - loss: 0.3479
# Epoch 12: val_loss did not improve from 0.34279
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8693 - loss: 0.3479 - val_accuracy: 0.8630 - val_loss: 0.3601
# Epoch 13/100
# 1638/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8708 - loss: 0.3408
# Epoch 13: val_loss improved from 0.34279 to 0.33919, saving model to /Users/keerthangowdas/Documents/Intrusion/working/Complete_model.keras
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8708 - loss: 0.3408 - val_accuracy: 0.8661 - val_loss: 0.3392
# Epoch 14/100
# 1638/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8717 - loss: 0.3368
# Epoch 14: val_loss improved from 0.33919 to 0.33782, saving model to /Users/keerthangowdas/Documents/Intrusion/working/Complete_model.keras
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8717 - loss: 0.3368 - val_accuracy: 0.8656 - val_loss: 0.3378
# Epoch 15/100
# 1649/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8725 - loss: 0.3339
# Epoch 15: val_loss improved from 0.33782 to 0.33182, saving model to /Users/keerthangowdas/Documents/Intrusion/working/Complete_model.keras
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8725 - loss: 0.3339 - val_accuracy: 0.8675 - val_loss: 0.3318
# Epoch 16/100
# 1636/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8733 - loss: 0.3303
# Epoch 16: val_loss improved from 0.33182 to 0.32851, saving model to /Users/keerthangowdas/Documents/Intrusion/working/Complete_model.keras
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8732 - loss: 0.3303 - val_accuracy: 0.8716 - val_loss: 0.3285
# Epoch 17/100
# 1643/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8727 - loss: 0.3480
# Epoch 17: val_loss did not improve from 0.32851
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8727 - loss: 0.3480 - val_accuracy: 0.8654 - val_loss: 0.3458
# Epoch 18/100
# 1647/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8723 - loss: 0.3355
# Epoch 18: val_loss did not improve from 0.32851
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8723 - loss: 0.3355 - val_accuracy: 0.8632 - val_loss: 0.3606
# Epoch 19/100
# 1645/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8742 - loss: 0.3324
# Epoch 19: val_loss did not improve from 0.32851
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8742 - loss: 0.3324 - val_accuracy: 0.8677 - val_loss: 0.3287
# Epoch 20/100
# 1639/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8716 - loss: 0.3389
# Epoch 20: val_loss did not improve from 0.32851
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8716 - loss: 0.3389 - val_accuracy: 0.8633 - val_loss: 0.3517
# Epoch 21/100
# 1643/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8718 - loss: 0.3386
# Epoch 21: val_loss did not improve from 0.32851
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8718 - loss: 0.3385 - val_accuracy: 0.8685 - val_loss: 0.3431
# Epoch 22/100
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8753 - loss: 0.3266
# Epoch 22: val_loss did not improve from 0.32851
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8753 - loss: 0.3266 - val_accuracy: 0.8650 - val_loss: 0.3360
# Epoch 23/100
# 1637/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8752 - loss: 0.3275
# Epoch 23: val_loss did not improve from 0.32851
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8752 - loss: 0.3275 - val_accuracy: 0.8698 - val_loss: 0.3395
# Epoch 24/100
# 1643/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8756 - loss: 0.3260
# Epoch 24: val_loss did not improve from 0.32851
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8755 - loss: 0.3260 - val_accuracy: 0.8684 - val_loss: 0.3346
# Epoch 25/100
# 1637/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8755 - loss: 0.3263
# Epoch 25: val_loss did not improve from 0.32851
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8755 - loss: 0.3263 - val_accuracy: 0.8663 - val_loss: 0.3332
# Epoch 26/100
# 1646/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8750 - loss: 0.3246
# Epoch 26: val_loss did not improve from 0.32851
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8750 - loss: 0.3246 - val_accuracy: 0.8685 - val_loss: 0.3306
# Epoch 26: early stopping
# Most_simple_model model in training
# (938583, 21) (938583,)
# Epoch 1/100
# 1646/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7661 - loss: 4.7998
# Epoch 1: val_loss improved from inf to 0.52789, saving model to /Users/keerthangowdas/Documents/Intrusion/working/Most_simple_model.keras
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.7663 - loss: 4.7896 - val_accuracy: 0.8249 - val_loss: 0.5279
# Epoch 2/100
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8452 - loss: 0.4317
# Epoch 2: val_loss improved from 0.52789 to 0.38688, saving model to /Users/keerthangowdas/Documents/Intrusion/working/Most_simple_model.keras
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8452 - loss: 0.4317 - val_accuracy: 0.8487 - val_loss: 0.3869
# Epoch 3/100
# 1639/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8448 - loss: 0.5344
# Epoch 3: val_loss did not improve from 0.38688
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8448 - loss: 0.5347 - val_accuracy: 0.8514 - val_loss: 0.3905
# Epoch 4/100
# 1633/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8570 - loss: 0.3654
# Epoch 4: val_loss improved from 0.38688 to 0.34026, saving model to /Users/keerthangowdas/Documents/Intrusion/working/Most_simple_model.keras
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8570 - loss: 0.3653 - val_accuracy: 0.8634 - val_loss: 0.3403
# Epoch 5/100
# 1642/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8659 - loss: 0.3392
# Epoch 5: val_loss improved from 0.34026 to 0.32736, saving model to /Users/keerthangowdas/Documents/Intrusion/working/Most_simple_model.keras
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8659 - loss: 0.3392 - val_accuracy: 0.8706 - val_loss: 0.3274
# Epoch 6/100
# 1644/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8671 - loss: 0.3366
# Epoch 6: val_loss improved from 0.32736 to 0.32309, saving model to /Users/keerthangowdas/Documents/Intrusion/working/Most_simple_model.keras
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8671 - loss: 0.3366 - val_accuracy: 0.8721 - val_loss: 0.3231
# Epoch 7/100
# 1634/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8608 - loss: 0.3575
# Epoch 7: val_loss improved from 0.32309 to 0.31671, saving model to /Users/keerthangowdas/Documents/Intrusion/working/Most_simple_model.keras
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8609 - loss: 0.3574 - val_accuracy: 0.8705 - val_loss: 0.3167
# Epoch 8/100
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8690 - loss: 0.3290
# Epoch 8: val_loss did not improve from 0.31671
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8690 - loss: 0.3290 - val_accuracy: 0.8605 - val_loss: 0.3420
# Epoch 9/100
# 1639/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8682 - loss: 0.3272
# Epoch 9: val_loss improved from 0.31671 to 0.30793, saving model to /Users/keerthangowdas/Documents/Intrusion/working/Most_simple_model.keras
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8682 - loss: 0.3271 - val_accuracy: 0.8777 - val_loss: 0.3079
# Epoch 10/100
# 1646/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8767 - loss: 0.3110
# Epoch 10: val_loss did not improve from 0.30793
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8767 - loss: 0.3110 - val_accuracy: 0.8709 - val_loss: 0.3192
# Epoch 11/100
# 1639/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8688 - loss: 0.3276
# Epoch 11: val_loss did not improve from 0.30793
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8687 - loss: 0.3278 - val_accuracy: 0.8265 - val_loss: 0.3987
# Epoch 12/100
# 1642/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8375 - loss: 0.3977
# Epoch 12: val_loss did not improve from 0.30793
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8375 - loss: 0.3976 - val_accuracy: 0.8528 - val_loss: 0.3584
# Epoch 13/100
# 1647/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8674 - loss: 0.3323
# Epoch 13: val_loss did not improve from 0.30793
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8674 - loss: 0.3322 - val_accuracy: 0.8773 - val_loss: 0.3082
# Epoch 14/100
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8767 - loss: 0.3104
# Epoch 14: val_loss improved from 0.30793 to 0.30007, saving model to /Users/keerthangowdas/Documents/Intrusion/working/Most_simple_model.keras
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8767 - loss: 0.3104 - val_accuracy: 0.8810 - val_loss: 0.3001
# Epoch 15/100
# 1636/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8786 - loss: 0.3073
# Epoch 15: val_loss did not improve from 0.30007
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8786 - loss: 0.3073 - val_accuracy: 0.8751 - val_loss: 0.3105
# Epoch 16/100
# 1647/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8788 - loss: 0.3049
# Epoch 16: val_loss did not improve from 0.30007
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8788 - loss: 0.3049 - val_accuracy: 0.8774 - val_loss: 0.3005
# Epoch 17/100
# 1637/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8771 - loss: 0.3095
# Epoch 17: val_loss did not improve from 0.30007
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8771 - loss: 0.3096 - val_accuracy: 0.8660 - val_loss: 0.3422
# Epoch 18/100
# 1634/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8724 - loss: 0.3232
# Epoch 18: val_loss did not improve from 0.30007
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8725 - loss: 0.3231 - val_accuracy: 0.8731 - val_loss: 0.3213
# Epoch 19/100
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8754 - loss: 0.3135
# Epoch 19: val_loss did not improve from 0.30007
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8754 - loss: 0.3135 - val_accuracy: 0.8790 - val_loss: 0.3089
# Epoch 20/100
# 1647/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8798 - loss: 0.3066
# Epoch 20: val_loss did not improve from 0.30007
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8798 - loss: 0.3066 - val_accuracy: 0.8790 - val_loss: 0.3060
# Epoch 21/100
# 1636/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8806 - loss: 0.3025
# Epoch 21: val_loss did not improve from 0.30007
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8806 - loss: 0.3025 - val_accuracy: 0.8765 - val_loss: 0.3071
# Epoch 22/100
# 1645/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8821 - loss: 0.2940
# Epoch 22: val_loss improved from 0.30007 to 0.29548, saving model to /Users/keerthangowdas/Documents/Intrusion/working/Most_simple_model.keras
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8821 - loss: 0.2940 - val_accuracy: 0.8824 - val_loss: 0.2955
# Epoch 23/100
# 1639/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8821 - loss: 0.2954
# Epoch 23: val_loss did not improve from 0.29548
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8821 - loss: 0.2954 - val_accuracy: 0.8790 - val_loss: 0.3017
# Epoch 24/100
# 1642/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8828 - loss: 0.2929
# Epoch 24: val_loss did not improve from 0.29548
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8828 - loss: 0.2929 - val_accuracy: 0.8757 - val_loss: 0.3086
# Epoch 25/100
# 1644/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8810 - loss: 0.2998
# Epoch 25: val_loss did not improve from 0.29548
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8810 - loss: 0.2998 - val_accuracy: 0.8747 - val_loss: 0.3160
# Epoch 26/100
# 1638/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8815 - loss: 0.2985
# Epoch 26: val_loss did not improve from 0.29548
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8815 - loss: 0.2985 - val_accuracy: 0.8784 - val_loss: 0.3028
# Epoch 27/100
# 1645/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8710 - loss: 0.3299
# Epoch 27: val_loss did not improve from 0.29548
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8710 - loss: 0.3299 - val_accuracy: 0.8775 - val_loss: 0.3085
# Epoch 28/100
# 1641/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8814 - loss: 0.2999
# Epoch 28: val_loss improved from 0.29548 to 0.29459, saving model to /Users/keerthangowdas/Documents/Intrusion/working/Most_simple_model.keras
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8815 - loss: 0.2999 - val_accuracy: 0.8826 - val_loss: 0.2946
# Epoch 29/100
# 1637/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8849 - loss: 0.2892
# Epoch 29: val_loss did not improve from 0.29459
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8849 - loss: 0.2892 - val_accuracy: 0.8801 - val_loss: 0.2971
# Epoch 30/100
# 1638/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8706 - loss: 0.3269
# Epoch 30: val_loss did not improve from 0.29459
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8706 - loss: 0.3271 - val_accuracy: 0.8639 - val_loss: 0.3435
# Epoch 31/100
# 1649/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8669 - loss: 0.3366
# Epoch 31: val_loss did not improve from 0.29459
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8669 - loss: 0.3366 - val_accuracy: 0.8672 - val_loss: 0.3318
# Epoch 32/100
# 1638/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8759 - loss: 0.3141
# Epoch 32: val_loss did not improve from 0.29459
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8759 - loss: 0.3141 - val_accuracy: 0.8773 - val_loss: 0.3099
# Epoch 33/100
# 1634/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8797 - loss: 0.3037
# Epoch 33: val_loss did not improve from 0.29459
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8797 - loss: 0.3038 - val_accuracy: 0.8394 - val_loss: 0.4221
# Epoch 34/100
# 1635/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8693 - loss: 0.3348
# Epoch 34: val_loss did not improve from 0.29459
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8694 - loss: 0.3345 - val_accuracy: 0.8787 - val_loss: 0.3129
# Epoch 35/100
# 1636/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8825 - loss: 0.2951
# Epoch 35: val_loss did not improve from 0.29459
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8825 - loss: 0.2951 - val_accuracy: 0.8813 - val_loss: 0.2950
# Epoch 36/100
# 1644/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8828 - loss: 0.2916
# Epoch 36: val_loss did not improve from 0.29459
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8828 - loss: 0.2917 - val_accuracy: 0.8758 - val_loss: 0.3145
# Epoch 37/100
# 1643/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8743 - loss: 0.3182
# Epoch 37: val_loss did not improve from 0.29459
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8743 - loss: 0.3182 - val_accuracy: 0.8779 - val_loss: 0.3053
# Epoch 38/100
# 1647/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8794 - loss: 0.3016
# Epoch 38: val_loss did not improve from 0.29459
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8794 - loss: 0.3016 - val_accuracy: 0.8786 - val_loss: 0.3012
# Epoch 38: early stopping
# No_regularization_model model in training
# (938583, 21) (938583,)
# Epoch 1/100
# 1639/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6994 - loss: 9.4846
# Epoch 1: val_loss improved from inf to 0.59808, saving model to /Users/keerthangowdas/Documents/Intrusion/working/No_regularization_model.keras
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.6997 - loss: 9.4311 - val_accuracy: 0.7629 - val_loss: 0.5981
# Epoch 2/100
# 1643/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7601 - loss: 0.6403
# Epoch 2: val_loss improved from 0.59808 to 0.54878, saving model to /Users/keerthangowdas/Documents/Intrusion/working/No_regularization_model.keras
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7602 - loss: 0.6402 - val_accuracy: 0.8046 - val_loss: 0.5488
# Epoch 3/100
# 1638/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7964 - loss: 0.5587
# Epoch 3: val_loss improved from 0.54878 to 0.52209, saving model to /Users/keerthangowdas/Documents/Intrusion/working/No_regularization_model.keras
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.7965 - loss: 0.5587 - val_accuracy: 0.8141 - val_loss: 0.5221
# Epoch 4/100
# 1639/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8122 - loss: 0.5309
# Epoch 4: val_loss improved from 0.52209 to 0.51123, saving model to /Users/keerthangowdas/Documents/Intrusion/working/No_regularization_model.keras
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8122 - loss: 0.5309 - val_accuracy: 0.8183 - val_loss: 0.5112
# Epoch 5/100
# 1644/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8147 - loss: 0.5325
# Epoch 5: val_loss improved from 0.51123 to 0.50326, saving model to /Users/keerthangowdas/Documents/Intrusion/working/No_regularization_model.keras
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8147 - loss: 0.5325 - val_accuracy: 0.8206 - val_loss: 0.5033
# Epoch 6/100
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8202 - loss: 0.5091
# Epoch 6: val_loss improved from 0.50326 to 0.49678, saving model to /Users/keerthangowdas/Documents/Intrusion/working/No_regularization_model.keras
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8202 - loss: 0.5091 - val_accuracy: 0.8244 - val_loss: 0.4968
# Epoch 7/100
# 1640/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8217 - loss: 0.5033
# Epoch 7: val_loss improved from 0.49678 to 0.49322, saving model to /Users/keerthangowdas/Documents/Intrusion/working/No_regularization_model.keras
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8217 - loss: 0.5033 - val_accuracy: 0.8245 - val_loss: 0.4932
# Epoch 8/100
# 1643/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8249 - loss: 0.4955
# Epoch 8: val_loss did not improve from 0.49322
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8249 - loss: 0.4955 - val_accuracy: 0.8255 - val_loss: 0.4935
# Epoch 9/100
# 1637/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8258 - loss: 0.4914
# Epoch 9: val_loss improved from 0.49322 to 0.48680, saving model to /Users/keerthangowdas/Documents/Intrusion/working/No_regularization_model.keras
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8258 - loss: 0.4914 - val_accuracy: 0.8263 - val_loss: 0.4868
# Epoch 10/100
# 1642/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8258 - loss: 0.5084
# Epoch 10: val_loss improved from 0.48680 to 0.48525, saving model to /Users/keerthangowdas/Documents/Intrusion/working/No_regularization_model.keras
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8258 - loss: 0.5085 - val_accuracy: 0.8252 - val_loss: 0.4852
# Epoch 11/100
# 1643/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8255 - loss: 0.4889
# Epoch 11: val_loss improved from 0.48525 to 0.48016, saving model to /Users/keerthangowdas/Documents/Intrusion/working/No_regularization_model.keras
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8255 - loss: 0.4889 - val_accuracy: 0.8271 - val_loss: 0.4802
# Epoch 12/100
# 1638/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8273 - loss: 0.4860
# Epoch 12: val_loss did not improve from 0.48016
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8273 - loss: 0.4860 - val_accuracy: 0.8264 - val_loss: 0.4837
# Epoch 13/100
# 1637/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8271 - loss: 0.4829
# Epoch 13: val_loss improved from 0.48016 to 0.47829, saving model to /Users/keerthangowdas/Documents/Intrusion/working/No_regularization_model.keras
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8271 - loss: 0.4829 - val_accuracy: 0.8273 - val_loss: 0.4783
# Epoch 14/100
# 1637/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8265 - loss: 0.4840
# Epoch 14: val_loss improved from 0.47829 to 0.47807, saving model to /Users/keerthangowdas/Documents/Intrusion/working/No_regularization_model.keras
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8265 - loss: 0.4840 - val_accuracy: 0.8273 - val_loss: 0.4781
# Epoch 15/100
# 1642/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8271 - loss: 0.4824
# Epoch 15: val_loss improved from 0.47807 to 0.47566, saving model to /Users/keerthangowdas/Documents/Intrusion/working/No_regularization_model.keras
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8271 - loss: 0.4824 - val_accuracy: 0.8278 - val_loss: 0.4757
# Epoch 16/100
# 1649/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8268 - loss: 0.4830
# Epoch 16: val_loss did not improve from 0.47566
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8268 - loss: 0.4830 - val_accuracy: 0.8269 - val_loss: 0.4782
# Epoch 17/100
# 1644/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8281 - loss: 0.4790
# Epoch 17: val_loss improved from 0.47566 to 0.47551, saving model to /Users/keerthangowdas/Documents/Intrusion/working/No_regularization_model.keras
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8281 - loss: 0.4790 - val_accuracy: 0.8280 - val_loss: 0.4755
# Epoch 18/100
# 1641/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8277 - loss: 0.4784
# Epoch 18: val_loss improved from 0.47551 to 0.47112, saving model to /Users/keerthangowdas/Documents/Intrusion/working/No_regularization_model.keras
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8277 - loss: 0.4784 - val_accuracy: 0.8288 - val_loss: 0.4711
# Epoch 19/100
# 1639/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8284 - loss: 0.4810
# Epoch 19: val_loss did not improve from 0.47112
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8284 - loss: 0.4810 - val_accuracy: 0.8274 - val_loss: 0.4776
# Epoch 20/100
# 1642/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8279 - loss: 0.4791
# Epoch 20: val_loss did not improve from 0.47112
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8279 - loss: 0.4792 - val_accuracy: 0.8282 - val_loss: 0.4767
# Epoch 21/100
# 1637/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8281 - loss: 0.4790
# Epoch 21: val_loss improved from 0.47112 to 0.46850, saving model to /Users/keerthangowdas/Documents/Intrusion/working/No_regularization_model.keras
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8281 - loss: 0.4790 - val_accuracy: 0.8294 - val_loss: 0.4685
# Epoch 22/100
# 1644/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8280 - loss: 0.4769
# Epoch 22: val_loss did not improve from 0.46850
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8280 - loss: 0.4769 - val_accuracy: 0.8289 - val_loss: 0.4724
# Epoch 23/100
# 1640/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8282 - loss: 0.4811
# Epoch 23: val_loss did not improve from 0.46850
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8282 - loss: 0.4811 - val_accuracy: 0.8274 - val_loss: 0.4754
# Epoch 24/100
# 1636/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8277 - loss: 0.4794
# Epoch 24: val_loss did not improve from 0.46850
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8277 - loss: 0.4794 - val_accuracy: 0.8286 - val_loss: 0.4721
# Epoch 25/100
# 1640/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8282 - loss: 0.4774
# Epoch 25: val_loss did not improve from 0.46850
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8282 - loss: 0.4774 - val_accuracy: 0.8285 - val_loss: 0.4740
# Epoch 26/100
# 1641/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8287 - loss: 0.4763
# Epoch 26: val_loss did not improve from 0.46850
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8287 - loss: 0.4763 - val_accuracy: 0.8287 - val_loss: 0.4753
# Epoch 27/100
# 1643/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8293 - loss: 0.4807
# Epoch 27: val_loss did not improve from 0.46850
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8293 - loss: 0.4808 - val_accuracy: 0.8275 - val_loss: 0.4773
# Epoch 28/100
# 1649/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8260 - loss: 0.5154
# Epoch 28: val_loss did not improve from 0.46850
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8260 - loss: 0.5154 - val_accuracy: 0.8291 - val_loss: 0.4734
# Epoch 29/100
# 1639/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8277 - loss: 0.5070
# Epoch 29: val_loss improved from 0.46850 to 0.46842, saving model to /Users/keerthangowdas/Documents/Intrusion/working/No_regularization_model.keras
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8277 - loss: 0.5069 - val_accuracy: 0.8298 - val_loss: 0.4684
# Epoch 30/100
# 1645/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8278 - loss: 0.4763
# Epoch 30: val_loss improved from 0.46842 to 0.41181, saving model to /Users/keerthangowdas/Documents/Intrusion/working/No_regularization_model.keras
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8278 - loss: 0.4763 - val_accuracy: 0.8269 - val_loss: 0.4118
# Epoch 31/100
# 1649/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8305 - loss: 0.4383
# Epoch 31: val_loss improved from 0.41181 to 0.39973, saving model to /Users/keerthangowdas/Documents/Intrusion/working/No_regularization_model.keras
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8305 - loss: 0.4383 - val_accuracy: 0.8423 - val_loss: 0.3997
# Epoch 32/100
# 1647/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8396 - loss: 0.4296
# Epoch 32: val_loss improved from 0.39973 to 0.39741, saving model to /Users/keerthangowdas/Documents/Intrusion/working/No_regularization_model.keras
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8396 - loss: 0.4296 - val_accuracy: 0.8450 - val_loss: 0.3974
# Epoch 33/100
# 1639/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8421 - loss: 0.4077
# Epoch 33: val_loss improved from 0.39741 to 0.38508, saving model to /Users/keerthangowdas/Documents/Intrusion/working/No_regularization_model.keras
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.8421 - loss: 0.4077 - val_accuracy: 0.8491 - val_loss: 0.3851
# Epoch 34/100
# 1649/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8456 - loss: 0.3981
# Epoch 34: val_loss improved from 0.38508 to 0.38091, saving model to /Users/keerthangowdas/Documents/Intrusion/working/No_regularization_model.keras
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8456 - loss: 0.3981 - val_accuracy: 0.8499 - val_loss: 0.3809
# Epoch 35/100
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8440 - loss: 0.4057
# Epoch 35: val_loss did not improve from 0.38091
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8440 - loss: 0.4057 - val_accuracy: 0.8511 - val_loss: 0.3844
# Epoch 36/100
# 1647/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8435 - loss: 0.4006
# Epoch 36: val_loss improved from 0.38091 to 0.37185, saving model to /Users/keerthangowdas/Documents/Intrusion/working/No_regularization_model.keras
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8435 - loss: 0.4006 - val_accuracy: 0.8547 - val_loss: 0.3718
# Epoch 37/100
# 1648/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8454 - loss: 0.4017
# Epoch 37: val_loss improved from 0.37185 to 0.36994, saving model to /Users/keerthangowdas/Documents/Intrusion/working/No_regularization_model.keras
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8454 - loss: 0.4017 - val_accuracy: 0.8485 - val_loss: 0.3699
# Epoch 38/100
# 1641/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8457 - loss: 0.3953
# Epoch 38: val_loss did not improve from 0.36994
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.8457 - loss: 0.3954 - val_accuracy: 0.8262 - val_loss: 0.4775
# Epoch 39/100
# 1644/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8303 - loss: 0.4610
# Epoch 39: val_loss did not improve from 0.36994
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8304 - loss: 0.4608 - val_accuracy: 0.8469 - val_loss: 0.3871
# Epoch 40/100
# 1643/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8486 - loss: 0.3895
# Epoch 40: val_loss improved from 0.36994 to 0.36748, saving model to /Users/keerthangowdas/Documents/Intrusion/working/No_regularization_model.keras
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.8486 - loss: 0.3894 - val_accuracy: 0.8513 - val_loss: 0.3675
# Epoch 41/100
# 1649/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8506 - loss: 0.3829
# Epoch 41: val_loss did not improve from 0.36748
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.8506 - loss: 0.3829 - val_accuracy: 0.8371 - val_loss: 0.4170
# Epoch 42/100
# 1649/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8217 - loss: 0.4465
# Epoch 42: val_loss did not improve from 0.36748
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.8217 - loss: 0.4465 - val_accuracy: 0.8506 - val_loss: 0.3994
# Epoch 43/100
# 1649/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8365 - loss: 0.4201
# Epoch 43: val_loss did not improve from 0.36748
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.8365 - loss: 0.4201 - val_accuracy: 0.8509 - val_loss: 0.3822
# Epoch 44/100
# 1643/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8454 - loss: 0.4050
# Epoch 44: val_loss improved from 0.36748 to 0.36288, saving model to /Users/keerthangowdas/Documents/Intrusion/working/No_regularization_model.keras
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.8454 - loss: 0.4050 - val_accuracy: 0.8537 - val_loss: 0.3629
# Epoch 45/100
# 1642/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8478 - loss: 0.3763
# Epoch 45: val_loss did not improve from 0.36288
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.8478 - loss: 0.3764 - val_accuracy: 0.8540 - val_loss: 0.3697
# Epoch 46/100
# 1647/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8483 - loss: 0.3745
# Epoch 46: val_loss improved from 0.36288 to 0.35556, saving model to /Users/keerthangowdas/Documents/Intrusion/working/No_regularization_model.keras
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.8483 - loss: 0.3745 - val_accuracy: 0.8527 - val_loss: 0.3556
# Epoch 47/100
# 1646/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8494 - loss: 0.3729
# Epoch 47: val_loss improved from 0.35556 to 0.34875, saving model to /Users/keerthangowdas/Documents/Intrusion/working/No_regularization_model.keras
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.8494 - loss: 0.3729 - val_accuracy: 0.8562 - val_loss: 0.3487
# Epoch 48/100
# 1646/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8548 - loss: 0.3639
# Epoch 48: val_loss did not improve from 0.34875
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.8548 - loss: 0.3639 - val_accuracy: 0.8526 - val_loss: 0.3677
# Epoch 49/100
# 1641/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8529 - loss: 0.3812
# Epoch 49: val_loss did not improve from 0.34875
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8529 - loss: 0.3812 - val_accuracy: 0.8582 - val_loss: 0.3631
# Epoch 50/100
# 1646/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8560 - loss: 0.3736
# Epoch 50: val_loss did not improve from 0.34875
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.8560 - loss: 0.3736 - val_accuracy: 0.8545 - val_loss: 0.3803
# Epoch 51/100
# 1647/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8516 - loss: 0.3946
# Epoch 51: val_loss did not improve from 0.34875
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.8516 - loss: 0.3946 - val_accuracy: 0.8235 - val_loss: 0.4040
# Epoch 52/100
# 1646/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8293 - loss: 0.4263
# Epoch 52: val_loss did not improve from 0.34875
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.8293 - loss: 0.4263 - val_accuracy: 0.8474 - val_loss: 0.4100
# Epoch 53/100
# 1646/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8356 - loss: 0.4475
# Epoch 53: val_loss did not improve from 0.34875
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.8356 - loss: 0.4474 - val_accuracy: 0.8432 - val_loss: 0.3955
# Epoch 54/100
# 1648/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8375 - loss: 0.4265
# Epoch 54: val_loss did not improve from 0.34875
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.8375 - loss: 0.4266 - val_accuracy: 0.8291 - val_loss: 0.4762
# Epoch 55/100
# 1638/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8238 - loss: 0.4843
# Epoch 55: val_loss did not improve from 0.34875
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.8238 - loss: 0.4843 - val_accuracy: 0.8274 - val_loss: 0.4755
# Epoch 56/100
# 1646/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8282 - loss: 0.4725
# Epoch 56: val_loss did not improve from 0.34875
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.8282 - loss: 0.4724 - val_accuracy: 0.8505 - val_loss: 0.3817
# Epoch 57/100
# 1636/1650 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8403 - loss: 0.4251
# Epoch 57: val_loss did not improve from 0.34875
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.8402 - loss: 0.4251 - val_accuracy: 0.8164 - val_loss: 0.4675
# Epoch 57: early stopping

# %%
for model_name, info_tuple in results.items():
    history = info_tuple[0].history

    print(f"{model_name.upper()}")
    plt.plot(history['accuracy'])
    plt.plot(history['val_accuracy'])
    plt.title(f'{model_name} accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='upper left')
    plt.show()

    plt.plot(history['loss'])
    plt.plot(history['val_loss'])
    plt.title(f'{model_name} accuracy')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='upper left')
    plt.show()
# Out:
# COMPLETE_MODEL
# MOST_SIMPLE_MODEL
# NO_REGULARIZATION_MODEL

# %%
def generate_confussion_matrix(y_true, y_predict, model_name: str, classes):
    predicted_labels_class = list(map(lambda x: classes[x], y_predict))
    y_true_labels_class = list(map(lambda x: classes[x], y_true))

    df_formatter = pd.DataFrame({
        "Clase predicha": predicted_labels_class,
        "Clase verdadera": y_true_labels_class
    })

    confussion_matrix = pd.crosstab(df_formatter["Clase predicha"],
                                    df_formatter["Clase verdadera"])
    plt.figure(figsize=(17, 5))
    plt.title(model_name)
    sns.heatmap(confussion_matrix, cmap="Blues", annot=True, fmt='g')
    plt.show()

# %%
tmp_model = load_model(f"/Users/keerthangowdas/Documents/Intrusion/working/Complete_model.keras")

# %% [markdown]
# # **Generación de metricas**

# %%
from sklearn.metrics import classification_report

# %%
for model_name in results.keys():
    model = load_model(f"/Users/keerthangowdas/Documents/Intrusion/working/{model_name}.keras")

    print(model_name)
    y_predict = np.argmax(model.predict(X_test), axis=1)
    generate_confussion_matrix(y_test, y_predict, model_name, class_names)
    print(classification_report(class_names[y_test], class_names[y_predict]))
# Out:
# Complete_model
# 3259/3259 ━━━━━━━━━━━━━━━━━━━━ 1s 312us/step
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#                precision    recall  f1-score   support
#
# BenignTraffic       0.67      0.91      0.77      2489
#          DDoS       0.89      0.97      0.93     76498
#           DoS       0.79      0.49      0.61     18053
#          MITM       0.70      0.11      0.19       706
#         Mirai       0.94      0.96      0.95      5838
#         Recon       0.00      0.00      0.00       703
#
#      accuracy                           0.87    104287
#     macro avg       0.67      0.57      0.57    104287
#  weighted avg       0.86      0.87      0.86    104287
#
# Most_simple_model
# 3259/3259 ━━━━━━━━━━━━━━━━━━━━ 1s 367us/step
#                precision    recall  f1-score   support
#
# BenignTraffic       0.69      0.90      0.78      2489
#          DDoS       0.90      0.96      0.93     76498
#           DoS       0.79      0.58      0.67     18053
#          MITM       0.71      0.02      0.03       706
#         Mirai       0.98      0.96      0.97      5838
#         Recon       0.67      0.52      0.58       703
#
#      accuracy                           0.89    104287
#     macro avg       0.79      0.66      0.66    104287
#  weighted avg       0.88      0.89      0.88    104287
#
# No_regularization_model
# 3259/3259 ━━━━━━━━━━━━━━━━━━━━ 1s 325us/step
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#                precision    recall  f1-score   support
#
# BenignTraffic       0.60      0.38      0.47      2489
#          DDoS       0.87      0.98      0.92     76498
#           DoS       0.83      0.44      0.57     18053
#          MITM       0.00      0.00      0.00       706
#         Mirai       0.80      0.94      0.87      5838
#         Recon       0.72      0.26      0.38       703
#
#      accuracy                           0.86    104287
#     macro avg       0.64      0.50      0.54    104287
#  weighted avg       0.85      0.86      0.84    104287
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
